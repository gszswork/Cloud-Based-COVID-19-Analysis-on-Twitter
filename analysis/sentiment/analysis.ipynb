# %%
# This is the file play in local





from test import *
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from textblob import TextBlob

from datetime import datetime
def get_time(elm):
    date = datetime.strptime(elm, '%a-%b-%d-%H:%M:%S-+0000-%Y')
    return date

from tqdm import tqdm

import re
def clean_dataset(text):
    # Remove hashtag while keeping hashtag text
    text = re.sub(r'#','', text)
    # Remove HTML special entities (e.g. &amp;)
    text = re.sub(r'\&\w*;', '', text)
    # Remove tickers
    #text = re.sub(r'\$\w*', '', text)
    # Remove hyperlinks
    #text = re.sub(r'https?:\/\/.*\/\w*', '', text)
    # Remove whitespace (including new line characters)
    text = re.sub(r'\s\s+','', text)
    text = re.sub(r'[ ]{2, }',' ',text)
    # Remove URL, RT, mention(@)
    text=  re.sub(r'http(\S)+', '',text)
    text=  re.sub(r'http ...', '',text)
    text=  re.sub(r'(RT|rt)[ ]*@[ ]*[\S]+','',text)
    text=  re.sub(r'RT[ ]?@','',text)
    text = re.sub(r'@[\S]+','',text)
    
    return text


    
def get_topN(table):
    
    delta = timedelta(hours=1)
    
    timeline = {}

    for tweet in tqdm(table):
        text = tweet.key[1]
        
        time_str = tweet.key[0].replace(' ','-')
        time = get_time(time_str)
        timeb = datetime(2020,1,1,0,0,0,0)
        while timeb < datetime.now():
            timeS = timeb
            timeE = timeb + delta
            if time > timeS and time < timeE:
                if timeS.strftime('%Y/%m/%d/%H') in timeline:
                    text = clean_dataset(text)
                    testimonial = TextBlob(text)
                    timeline[timeS.strftime('%Y/%m/%d/%H')].append(testimonial.sentiment.polarity)
                    
                else:
                    text = clean_dataset(text)
                    testimonial = TextBlob(text)
                    timeline[timeS.strftime('%Y/%m/%d/%H')] = [testimonial.sentiment.polarity]
            timeb += delta
        #print(timeline.keys())

    return timeline


import json
from datetime import timedelta
cdb = CouchDB()
e_db = cdb.get_db('melbourne20_21')
# a = cdb.create_db('hotword_50')
# h_db = cdb.get_db('hotword_50')
table = e_db.iterview('_design/dictionary/_view/textdate',3000)
timeline = get_topN(table)
# with open('timeline.json','w') as jj:
#     json.dump(timeline, jj)

# for k,v in timeline.items():
#     print(k)
#     print(len(list(v.keys())))
    #h_db[k] = v

'''{
            "name": "Python: Django",
            "type": "python",
            "request": "launch",
            "program": "${workspaceFolder}/backend/manage.py",
            "args": [
                "runserver"
            ],
            "django": true
        }'''
# Out:
# 0it [00:00, ?it/s]
# Success connected CouchDB Server with url:{ http://admin:admin@172.26.133.210:5984/ }
# Success return database of melbourne20_21
# 1054150it [1:51:47, 157.15it/s]
# '{\n            "name": "Python: Django",\n            "type": "python",\n            "request": "launch",\n            "program": "${workspaceFolder}/backend/manage.py",\n            "args": [\n                "runserver"\n            ],\n            "django": true\n        }'

# %%
sentiment = {}
for k,v in timeline.items():
    count = 0
    score = []
    for i in v:
        if i != 0:
            score.append(i)
    sentiment[k] = {'sentiment_score':round(sum(score)/(len(score)),4)}

# %%
sentiment['2020/10/02/09']
# Out:
# {'sentiment_score': 0.108}

# %%
#To retrieve the day with some overall happy twitter
sentiment = {}
sentiment_month = []
sentiment_day = {}
for k,v in timeline.items():
    count = 0
    score = []
    for i in v:
        if i != 0:
            score.append(i)
    sentiment[k] = {'sentiment_score':round(sum(score)/(len(score)),4)}
    if  round(sum(score)/(len(score)),4) > 0.2:
        print(k, round(sum(score)/(len(score)),4))
        sentiment_month.append((k,v))
        day = k[0:10]
        if day not in sentiment_day.keys():
            sentiment_day[day] = [round(sum(score)/(len(score)),4)]
        else:
            sentiment_day[day].append(round(sum(score)/(len(score)),4))
# Out:
# 2020/12/04/00 0.214
# 2020/12/04/01 0.2136
# 2020/12/04/02 0.203
# 2020/12/04/07 0.2086
# 2020/12/04/09 0.2028
# 2020/12/04/15 0.201
# 2020/12/04/16 0.206
# 2020/12/04/17 0.2269
# 2020/12/04/18 0.2925
# 2020/12/04/19 0.221
# 2020/12/11/09 0.2198
# 2020/12/11/11 0.2274
# 2020/12/11/19 0.255
# 2020/12/18/04 0.2036
# 2020/12/18/11 0.2016
# 2020/12/25/00 0.2212
# 2020/12/25/04 0.2403
# 2020/12/25/05 0.2449
# 2020/12/25/07 0.2191
# 2020/12/25/09 0.2685
# 2020/12/25/10 0.2427
# 2020/12/25/11 0.2958
# 2020/12/25/13 0.2308
# 2020/12/25/15 0.2255
# 2020/12/25/16 0.2415
# 2020/12/25/17 0.2738
# 2020/12/25/19 0.2602
# 2020/12/25/21 0.2338
# 2020/12/25/22 0.2291
# 2021/01/01/02 0.2089
# 2021/01/01/03 0.2121
# 2021/01/01/10 0.2164
# 2021/01/01/11 0.2201
# 2021/01/01/13 0.2142
# 2021/01/01/18 0.2054
# 2021/01/01/19 0.2077
# 2021/01/08/12 0.2115
# 2021/01/08/13 0.2084
# 2020/11/13/04 0.2153
# 2020/11/13/08 0.207
# 2020/11/13/09 0.202
# 2020/11/13/12 0.2112
# 2020/11/13/13 0.2176
# ...

# %%
happyday = []
for i,j in sentiment_day.items():
    if len(j) >= 4:
        happyday.append(i)

# %%
oct_2020 = 0
nov_2020 = 0
dec_2020 = 0
jan_2021 = 0
for i in happyday:
    if i[0:7] == '2020/10':
        oct_2020 += 1 
    elif i[0:7] == '2020/11':
        nov_2020 += 1 
    elif i[0:7] == '2020/12':
        dec_2020 += 1 
    elif i[0:7] == '2021/01':
        jan_2021 += 1

# %%
jan_2021
# Out:
# 4

# %%
happy_day = {}
happy_day['2020/10'] = oct_2020
happy_day['2020/11'] = nov_2020
happy_day['2020/12'] = dec_2020
happy_day['2021/01'] = jan_2021

# %%
happy_day
# Out:
# {'2020/10': 4, '2020/11': 6, '2020/12': 8, '2021/01': 4}

# %%
a = cdb.create_db('sentiment_analysis')
h_db = cdb.get_db('sentiment_analysis')


for k,v in sentiment.items():
    h_db[k] = v
# Out:
# Database [sentiment_analysis] created
# Success return database of sentiment_analysis

# %%
e_db = cdb.get_db('melbourne20_21')
# a = cdb.create_db('hotword_50')
# h_db = cdb.get_db('hotword_50')
table = e_db.view('_design/dictionary/_view/date')
# Out:
# Success return database of melbourne20_21

# %%
import json
from datetime import timedelta
from test import *
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from textblob import TextBlob

from datetime import datetime
cdb = CouchDB()
e_db = cdb.get_db('covid_test')
table = e_db.view('_design/newdoc/_view/datetext' ,group=True)
# Out:
# Success connected CouchDB Server with url:{ http://admin:admin@172.26.133.210:5984/ }
# Success return database of covid_test

# %%
def get_time(elm):
    date = datetime.strptime(elm, '%Y-%m-%d %H:%M:%S+0000')
    return date

# %%
def get_sentiment(table):
    
    delta = timedelta(hours=1)
    
    timeline = {}

    for tweet in table:
        text = tweet.key[1]
        
        time_str = tweet.key[0]
        time = get_time(time_str)
        timeb = datetime(2020,1,1,0,0,0,0)
        while timeb < datetime.now():
            timeS = timeb
            timeE = timeb + delta
            if time > timeS and time < timeE:
                if timeS.strftime('%Y/%m/%d/%H') in timeline:
                    text = clean_dataset(text)
                    testimonial = TextBlob(text)
                    timeline[timeS.strftime('%Y/%m/%d/%H')].append(testimonial.sentiment.polarity)
                    
                else:
                    text = clean_dataset(text)
                    testimonial = TextBlob(text)
                    timeline[timeS.strftime('%Y/%m/%d/%H')] = [testimonial.sentiment.polarity]
            timeb += delta
        #print(timeline.keys())

    return timeline

# %%
timeline = get_sentiment(table)

# %%
sentiment = {}
for k,v in timeline.items():
    count = 0
    score = []
    for i in v:
        if i != 0:
            score.append(i)
    sentiment[k] = {'sentiment_score':round(sum(score)/(len(score)+0.0001),4)}

# %%
len(sentiment)
# Out:
# 3444

# %%
sentiment
# Out:
# {'2020/01/09/00': {'sentiment_score': 0.0924},
#  '2020/01/23/12': {'sentiment_score': 0.0455},
#  '2020/01/25/22': {'sentiment_score': 0.2143},
#  '2020/01/27/03': {'sentiment_score': 0.0},
#  '2020/01/27/14': {'sentiment_score': 0.158},
#  '2020/01/27/17': {'sentiment_score': 0.125},
#  '2020/01/27/20': {'sentiment_score': 0.0},
#  '2020/01/28/12': {'sentiment_score': 0.1463},
#  '2020/01/28/14': {'sentiment_score': 0.125},
#  '2020/01/28/18': {'sentiment_score': 0.0833},
#  '2020/01/29/01': {'sentiment_score': 0.0},
#  '2020/01/29/02': {'sentiment_score': 0.2},
#  '2020/01/29/12': {'sentiment_score': 0.0},
#  '2020/01/29/15': {'sentiment_score': 0.0},
#  '2020/01/29/17': {'sentiment_score': -0.671},
#  '2020/01/29/22': {'sentiment_score': 0.0},
#  '2020/01/30/08': {'sentiment_score': 0.2273},
#  '2020/01/30/11': {'sentiment_score': 0.1199},
#  '2020/01/30/14': {'sentiment_score': 0.0},
#  '2020/01/30/15': {'sentiment_score': 0.0},
#  '2020/01/30/16': {'sentiment_score': 0.1083},
# ...

# %%
import json
with open('sentiment_score_covid_test.json','w') as jj:
    json.dump(sentiment,jj)

# %%
cdb = CouchDB()
cdb.create_db('sentiment_covid')
h_db = cdb.get_db('sentiment_covid')


for k,v in sentiment.items():
    h_db[k] = v
# Out:
# Success connected CouchDB Server with url:{ http://admin:admin@172.26.133.210:5984/ }
# In create_db(): Database [sentiment_covid] already exist
# Success return database of sentiment_covid

# %%
from tqdm import tqdm
def get_sentiment_v2(table):
    
    
    
    timeline = {}

    for tweet in tqdm(table):
        text = tweet.key[3]
        location = tweet.key[0]
        geo = tweet.key[1]
        text = clean_dataset(text)
        testimonial = TextBlob(text)
        timeline[text] = {'lga': location, 'sentiment_score': testimonial.sentiment.polarity, 'text': text,'geo':geo}
        #print(timeline.keys())

    return timeline

# %%
cdb = CouchDB()
e_db = cdb.get_db('has_location_in_vic')
# a = cdb.create_db('hotword_50')
# h_db = cdb.get_db('hotword_50')
table = e_db.iterview('_design/dictionary/_view/newviews',3000)
timeline = get_sentiment_v2(table)
# Out:
# 0it [00:00, ?it/s]
# Success connected CouchDB Server with url:{ http://admin:admin@172.26.133.210:5984/ }
# Success return database of has_location_in_vic
# 22247it [00:07, 2798.58it/s]

# %%
from tqdm import tqdm
from textblob import TextBlob
def get_sentiment_v3(table):
    
    
    
    timeline = {}
    count = 1
    for tweet in table:
        text = tweet[3]
        location = tweet[0]
        geo = tweet[1]
        clean_text = clean_dataset(text)
        testimonial = TextBlob(clean_text)
        time = tweet[2]
        timeline[str(count)] = {'lga': location, 'sentiment_score': round(testimonial.sentiment.polarity,3), 'text': text,'geo':geo}
        #print(timeline.keys())
        count +=1
    return timeline

# %%
from tqdm import tqdm
from textblob import TextBlob
def get_sentiment_v4(tweet):
    
    
    
    timeline = {}


    text = tweet[3]
    location = tweet[0]
    geo = tweet[1]
    clean_text = clean_dataset(text)
    testimonial = TextBlob(clean_text)
    time = tweet[2]
    time_text = time + text
    timeline[time_text] = {'lga': location, 'sentiment_score': round(testimonial.sentiment.polarity,3), 'text': text,'geo':geo}
        #print(timeline.keys())

    return timeline

# %%
import json
with open('save.json','r') as jj:
    timeline = json.loads(jj.read())

# %%
timeline
# Out:
# {'556b4c43d71d9c2d2f7e49b862e8b119': ['ALPINE',
#   [-36.7532313, 147.0111681],
#   'Fri May 14 21:45:58 +0000 2021',
#   '@BrockleyKyle @IvanSpyrdz @CricketNSW @PaulBrockley I didn’t recognise him with his clothes on to be honest 😉😉',
#   'en'],
#  '556b4c43d71d9c2d2f7e49b862e8b107': ['ALPINE',
#   [-36.7532313, 147.0111681],
#   'Fri May 14 21:46:46 +0000 2021',
#   'RT @DerekRobinson2: @DougCameron51 @australian @TroyBramston @AlboMP The “Arsetralian” never fails to disappoint!',
#   'en'],
#  '556b4c43d71d9c2d2f7e49b862e8a68e': ['ALPINE',
#   [-36.7532313, 147.0111681],
#   'Fri May 14 21:47:24 +0000 2021',
#   'RT @retvilldotnet: @FlickReynolds @joybelle05 #auspol https://t.co/aNiAKWlO8b',
#   'und'],
#  '556b4c43d71d9c2d2f7e49b862e89c66': ['ALPINE',
#   [-36.7532313, 147.0111681],
#   'Fri May 14 21:47:41 +0000 2021',
#   'RT @DerekRobinson2: @LesStonehouse @LiberalAus They are coming across as a bunch of “two bob turkeys” praising themselves for a lousy job w…',
#   'en'],
# ...

# %%
clean_timeline = []
add_timeline = []
final_timeline = []
for i, j in timeline.items():
    text_time = j[2]+j[3]
    if j[0] == 'MELBOURNE':
        if text_time not in clean_timeline:
            clean_timeline.append(text_time)
            add_timeline.append(j)
final_timeline = add_timeline
for i, j in timeline.items():
    text_time = j[2]+j[3]

    if text_time not in clean_timeline:
        clean_timeline.append(text_time)
        final_timeline.append(j)

# %%
timeline_pro = get_sentiment_v3(final_timeline)

# %%
len(timeline_pro)
# Out:
# 12469

# %%
timeline_pro
# Out:
# {'1': {'lga': 'ALPINE',
#   'sentiment_score': 0.6,
#   'text': '@BrockleyKyle @IvanSpyrdz @CricketNSW @PaulBrockley I didn’t recognise him with his clothes on to be honest 😉😉',
#   'geo': [-36.7532313, 147.0111681]},
#  '2': {'lga': 'ALPINE',
#   'sentiment_score': 0.312,
#   'text': 'RT @DerekRobinson2: @DougCameron51 @australian @TroyBramston @AlboMP The “Arsetralian” never fails to disappoint!',
#   'geo': [-36.7532313, 147.0111681]},
#  '3': {'lga': 'ALPINE',
#   'sentiment_score': 0.0,
#   'text': 'RT @retvilldotnet: @FlickReynolds @joybelle05 #auspol https://t.co/aNiAKWlO8b',
#   'geo': [-36.7532313, 147.0111681]},
#  '4': {'lga': 'ALPINE',
#   'sentiment_score': -0.5,
#   'text': 'RT @DerekRobinson2: @LesStonehouse @LiberalAus They are coming across as a bunch of “two bob turkeys” praising themselves for a lousy job w…',
#   'geo': [-36.7532313, 147.0111681]},
#  '5': {'lga': 'ALPINE',
#   'sentiment_score': 0.0,
#   'text': 'RT @DerekRobinson2: https://t.co/yBWqGp4wUd',
# ...

# %%
for j,i in timeline_pro.items():
    print(j,i)
    if i['lga'] == 'MELBOURNE':
        print(1)
# Out:
# Fri May 14 21:45:58 +0000 2021@BrockleyKyle @IvanSpyrdz @CricketNSW @PaulBrockley I didn’t recognise him with his clothes on to be honest 😉😉 {'lga': 'ALPINE', 'sentiment_score': 0.6, 'text': '@BrockleyKyle @IvanSpyrdz @CricketNSW @PaulBrockley I didn’t recognise him with his clothes on to be honest 😉😉', 'geo': [-36.7532313, 147.0111681]}
# Fri May 14 21:46:46 +0000 2021RT @DerekRobinson2: @DougCameron51 @australian @TroyBramston @AlboMP The “Arsetralian” never fails to disappoint! {'lga': 'ALPINE', 'sentiment_score': 0.3125, 'text': 'RT @DerekRobinson2: @DougCameron51 @australian @TroyBramston @AlboMP The “Arsetralian” never fails to disappoint!', 'geo': [-36.7532313, 147.0111681]}
# Fri May 14 21:47:24 +0000 2021RT @retvilldotnet: @FlickReynolds @joybelle05 #auspol https://t.co/aNiAKWlO8b {'lga': 'ALPINE', 'sentiment_score': 0.0, 'text': 'RT @retvilldotnet: @FlickReynolds @joybelle05 #auspol https://t.co/aNiAKWlO8b', 'geo': [-36.7532313, 147.0111681]}
# ...

# %%
sentiment = {}
count = 1
for v in timeline.values():
    a = 'tweet'+ str(count)
    sentiment[a] = v
    count+=1

# %%
sentiment
# Out:
# {'tweet1': {'lga': 'ALPINE',
#   'sentiment_score': 0.6,
#   'text': '    I didn’t recognise him with his clothes on to be honest 😉😉',
#   'geo': [-36.7532313, 147.0111681]},
#  'tweet2': {'lga': 'ALPINE',
#   'sentiment_score': 0.3125,
#   'text': '     The “Arsetralian” never fails to disappoint!',
#   'geo': [-36.7532313, 147.0111681]},
#  'tweet3': {'lga': 'ALPINE',
#   'sentiment_score': 0.0,
#   'text': '   auspol ',
#   'geo': [-36.7532313, 147.0111681]},
#  'tweet4': {'lga': 'ALPINE',
#   'sentiment_score': -0.5,
#   'text': '   They are coming across as a bunch of “two bob turkeys” praising themselves for a lousy job w…',
#   'geo': [-36.7532313, 147.0111681]},
#  'tweet5': {'lga': 'YARRIAMBIACK',
#   'sentiment_score': 0.0,
#   'text': ' ',
#   'geo': [-35.9703773, 142.4465474]},
#  'tweet6': {'lga': 'ALPINE',
#   'sentiment_score': 0.49242424242424243,
#   'text': '  Their own bank balances are very healthy - positive for them only😡.',
# ...

# %%
from test import *
cdb = CouchDB()
cdb.create_db('sentiment_location_lga')
h_db = cdb.get_db('sentiment_location_lga')

for k,v in timeline_pro.items():
    h_db[k] = v
# Out:
# Success connected CouchDB Server with url:{ http://admin:admin@172.26.134.73:5984/ }
# Database [sentiment_location_lga] created
# Success return database of sentiment_location_lga
